# %% [markdown]
# # Fizz Buzz
#
# Given an integer n, return a string array answer (1-indexed) where:
#
# - answer[i] == "FizzBuzz" if i is divisible by 3 and 5.
# - answer[i] == "Fizz" if i is divisible by 3.
# - answer[i] == "Buzz" if i is divisible by 5.
# - answer[i] == i (as a string) if none of the above conditions are true.
#
#
# Example 1:
# ```
# Input: n = 3
# Output: ["1","2","Fizz"]
# Example 2:
#
# Input: n = 5
# Output: ["1","2","Fizz","4","Buzz"]
# Example 3:
#
# Input: n = 15
# Output: ["1","2","Fizz","4","Buzz","Fizz","7","8","Fizz","Buzz","11","Fizz","13","14","FizzBuzz"]
# ```
#
# Constraints:
#
# - 1 <= n <= 104

# %%
# Ali's solution (Straightforward solution)
def fizzBuzz(n):
    if n<1:
        return []
    lst = []
    i=1
    while i<=n:
        if i % 3 == 0 and i % 5 ==0:
            lst.append("FizzBuzz")
        elif i%3 ==0:
            lst.append("Fizz")
        elif i%5 == 0:
            lst.append("Buzz")
        else:
            lst.append(str(i))
        i+=1
    return lst

# %%
fizzBuzz(15)
# Out:
# ['1',
#  '2',
#  'Fizz',
#  '4',
#  'Buzz',
#  'Fizz',
#  '7',
#  '8',
#  'Fizz',
#  'Buzz',
#  '11',
#  'Fizz',
#  '13',
#  '14']

# %%
# Leetcode Sol2: String concatanation
def fizzBuzz(n):
    answer = []
    for i in range(1,n+1):
        currStr = ''
        if i%3==0:
            currStr+='Fizz'
        if i%5==0:
            currStr+='Buzz'
        if currStr=='':
            currStr = str(i)
        answer.append(currStr)
    return answer

# %%
fizzBuzz(15)
# Out:
# ['1',
#  '2',
#  'Fizz',
#  '4',
#  'Buzz',
#  'Fizz',
#  '7',
#  '8',
#  'Fizz',
#  'Buzz',
#  '11',
#  'Fizz',
#  '13',
#  '14',
#  'FizzBuzz']

# %%
def fizzBuzz(n):
    answer = []
    divisors = {3:"Fizz",5:"Buzz"}

    for i in range(1,n+1):
        currStr = []
        for k in divisors.keys():
            if i%k ==0:
                currStr.append(divisors[k])
        if not currStr:
            currStr.append(str(i))
        answer.append(''.join(currStr))
    return answer

# %%
fizzBuzz(15)
# Out:
# ['1',
#  '2',
#  'Fizz',
#  '4',
#  'Buzz',
#  'Fizz',
#  '7',
#  '8',
#  'Fizz',
#  'Buzz',
#  '11',
#  'Fizz',
#  '13',
#  '14',
#  'FizzBuzz']

# %% [markdown]
# # Count Primes
# Given an integer n, return the number of prime numbers that are strictly less than n.
#
#
# Example 1:
# ```
# Input: n = 10
# Output: 4
# Explanation: There are 4 prime numbers less than 10, they are 2, 3, 5, 7.
# Example 2:
#
# Input: n = 0
# Output: 0
# Example 3:
#
# Input: n = 1
# Output: 0
# ```
#
# Constraints:
#
# - 0 <= n <= 5 * 106
#
# Hint #1
# - Checking all the integers in the range [1, n - 1] is not efficient. Think about a better approach.
# Hint #2
# - Since most of the numbers are not primes, we need a fast approach to exclude the non-prime integers.
# Hint #3
# - Use Sieve of Eratosthenes.

# %%
# Ali's solution (Naive approach) - time exceed limit
def findPrime(n):
    if n<2 :
        return 0
    
    divisors = []

    for i in range(2,n):

        if not divisors:
            divisors.append(i)
            continue
        
        if isInDivisor(i,divisors):
            divisors.append(i)
    return len(divisors)

def isInDivisor(num,divLst):
    for k in divLst:
        if num%k ==0:
            return False
    return True

# %%
#Ali's solution using the hint:  Sieve of Eratosthenes apprach
def countPrimes(n):
    if n<2 :
        return 0
    
    mark = [False, False,]+[True]*(n-2)

    for i in range(2,int(n**0.5)+1):
        if mark[i]:
            for j in range(i*i,n,i):
                mark[j]=False
    return sum(mark)

# %%
countPrimes(120)
# Out:
# 30

# %%
findPrime(120)
# Out:
# 30

# %%
import math
# Leetcode solution for faster and more efficient in Python:
def countPrimes(n):
    if n<2 :
        return 0
    
    mark = [False, False,]+[True]*(n-2)

    for i in range(2,int(n**0.5)+1):
        if mark[i]:
            mark[i*i:n:i]=[False]*math.ceil(n/i-i)
    return sum(mark)

# %%
countPrimes(120)
# Out:
# 30

# %% [markdown]
# # Power of Three
#
# Given an integer n, return true if it is a power of three. Otherwise, return false.
#
# An integer n is a power of three, if there exists an integer x such that n == 3x.
#
# Example 1:
# ```
# Input: n = 27
# Output: true
# Explanation: 27 = 33
# Example 2:
#
# Input: n = 0
# Output: false
# Explanation: There is no x where 3x = 0.
# Example 3:
#
# Input: n = -1
# Output: false
# Explanation: There is no x where 3x = (-1).
# ```
#
# Constraints:
#
# - -231 <= n <= 231 - 1
#
#
# Follow up: Could you solve it without loops/recursion?

# %%
def isPowerOfThree(n):
    if n<1:
        return False

    while n%3==0:
        n//=3
        
        
    return n==1

# %%
isPowerOfThree(27)
# Out:
# True

# %%
import math
def isPowerOfThree(n):
    if (math.log(n)/math.log(3))%3 == 0:
        return True
    return False

# %%
import math
(math.log(27)/math.log(3))%3 == 0
# Out:
# True

# %%
#smart solution which makes the complexity O(1) for both time and space

#what is the max_INT that is also a power of 3? 3**[log3(MAX_INT)]=3**19
def isPowerOfThree(n):
    return n>0 and 3**19%n==0

# %%
isPowerOfThree(80)
# Out:
# False

# %% [markdown]
# # Roman to Integer
#
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
# ```
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# ```
# For example, 2 is written as II in Roman numeral, just two ones added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# - `I` can be placed before V (5) and X (10) to make 4 and 9.
# - `X` can be placed before L (50) and C (100) to make 40 and 90.
# - `C` can be placed before D (500) and M (1000) to make 400 and 900.
# Given a roman numeral, convert it to an integer.
#
#
#
# Example 1:
# ```
# Input: s = "III"
# Output: 3
# Explanation: III = 3.
# Example 2:
#
# Input: s = "LVIII"
# Output: 58
# Explanation: L = 50, V= 5, III = 3.
# Example 3:
#
# Input: s = "MCMXCIV"
# Output: 1994
# Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.
# ```
#
# Constraints:
#
# - 1 <= s.length <= 15
# - s contains only the characters ('I', 'V', 'X', 'L', 'C', 'D', 'M').
# - It is guaranteed that s is a valid roman numeral in the range [1, 3999].
#
# Hint #1
# Problem is simpler to solve by working the string from back to front and using a map.

# %%
# Ali's solution using the hint (use string, map, back to front)
def romanToInt(s):
    romanDic = {'I':1,'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000,'IV':4,'IX':9,'XL':40,'XC':90,'CD':400,'CM':900}
    num = 0
    i=len(s)-1
    while i>-1:
        if s[i-1]+s[i] in romanDic and i>0:
            num+=romanDic[s[i-1]+s[i]]
            i-=2
        elif s[i] in romanDic:
            num+=romanDic[s[i]]
            i-=1
    return num

# %%
s = "MMMCDXC"
romanToInt(s)
# Out:
# XC
# CD
# M
# M
# M
# 3490

# %%
#Leetcode solution: Left to right pass (Improved from simple pass)
values = {'I':1,'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000,'IV':4,'IX':9,'XL':40,'XC':90,'CD':400,'CM':900}

class Solution:
    def romanToInt(self,s):
        total = 0
        i = 0
        while i<len(s):
            # This is the substractive case.
            if i<len(s)-1 and s[i:i+2] in values:
                total+=values[s[i:i+2]]
                i+=2
            else:
                total+=values[s[i]]
                i+=1
        return total

# %%
sol = Solution()

# %%
sol.romanToInt(s)
# Out:
# 3490

# %%
#Best solution: Backward, without adding extra to dic and checking the next symbol not to go over the end of string.
values = {'I':1,'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000}

class Solution:
    def romanToInt(self,s):
        total = values.get(s[-1])
        for i in range(len(s)-1,0,-1):
            if values[s[i-1]]<values[s[i]]:
                total-=values[s[i-1]]
            else:
                total+=values[s[i-1]]
        return total

# %%
sol = Solution()
sol.romanToInt(s)
# Out:
# 3490
